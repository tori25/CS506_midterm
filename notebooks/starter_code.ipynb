# %% [markdown]
# ## Exploration

# %% [markdown]
# ## Feature Extraction

# %% [markdown]
# ## Create Model

# %% [markdown]
# ## Fine Tuning

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ## Create the Kaggle submission

# %% [markdown]
# Now you can upload the `submission.csv` to kaggle
